# %%
import pandas as pd
import numpy as np

# %%
location = "datasets/DC_Properties.csv"
df = pd.read_csv("datasets/DC_Properties.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
# Out:
#    Unnamed: 0  BATHRM  HF_BATHRM           HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 0           0       4          0      Warm Cool  Y        2.0      8      4
# 1           1       3          1      Warm Cool  Y        2.0     11      5
# 2           2       3          1  Hot Water Rad  Y        2.0      9      5
# 3           3       3          1  Hot Water Rad  Y        2.0      8      5
# 4           4       2          1      Warm Cool  Y        1.0     11      3
# 5           5       3          2  Hot Water Rad  Y        1.0     10      5
# 6           6       1          0      Warm Cool  Y        2.0      5      2
# 7           7       3          1  Hot Water Rad  Y        2.0      8      4
# 8           8       3          1      Warm Cool  Y        2.0      7      3
# 9           9       1          1  Hot Water Rad  Y        1.0      6      2
#
#       AYB  YR_RMDL   ...     LONGITUDE  ASSESSMENT_NBHD ASSESSMENT_SUBNBHD  \
# ...

# %%
dupe = df.duplicated()

# %%
df.loc[dupe]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, BATHRM, HF_BATHRM, HEAT, AC, NUM_UNITS, ROOMS, BEDRM, AYB, YR_RMDL, EYB, STORIES, SALEDATE, PRICE, QUALIFIED, SALE_NUM, GBA, BLDG_NUM, STYLE, STRUCT, GRADE, CNDTN, EXTWALL, ROOF, INTWALL, KITCHENS, FIREPLACES, USECODE, LANDAREA, GIS_LAST_MOD_DTTM, SOURCE, CMPLX_NUM, LIVING_GBA, FULLADDRESS, CITY, STATE, ZIPCODE, NATIONALGRID, LATITUDE, LONGITUDE, ASSESSMENT_NBHD, ASSESSMENT_SUBNBHD, CENSUS_TRACT, CENSUS_BLOCK, WARD, SQUARE, X, Y, QUADRANT]
# Index: []
#
# [0 rows x 49 columns]

# %%
df.tail(10)
# Out:
#         Unnamed: 0  BATHRM  HF_BATHRM        HEAT AC  NUM_UNITS  ROOMS  BEDRM  \
# 158947      158947       2          0  Forced Air  Y        NaN      4      2
# 158948      158948       2          0  Forced Air  Y        NaN      4      2
# 158949      158949       1          1  Forced Air  Y        NaN      4      1
# 158950      158950       3          0  Forced Air  Y        NaN      5      3
# 158951      158951       3          1  Forced Air  Y        NaN      5      3
# 158952      158952       1          0  Forced Air  Y        NaN      3      1
# 158953      158953       1          0  Forced Air  Y        NaN      4      2
# 158954      158954       2          0  Forced Air  Y        NaN      4      2
# 158955      158955       1          0   Warm Cool  Y        NaN      2      0
# 158956      158956       1          0   Warm Cool  Y        NaN      2      0
#
#            AYB  YR_RMDL   ...     LONGITUDE       ASSESSMENT_NBHD  \
# ...

# %%
df.describe()
# Out:
#           Unnamed: 0         BATHRM      HF_BATHRM      NUM_UNITS  \
# count  158957.000000  158957.000000  158957.000000  106696.000000
# mean    79478.000000       1.810678       0.458237       1.198039
# std     45887.077707       0.976396       0.587571       0.596924
# min         0.000000       0.000000       0.000000       0.000000
# 25%     39739.000000       1.000000       0.000000       1.000000
# 50%     79478.000000       2.000000       0.000000       1.000000
# 75%    119217.000000       2.000000       1.000000       1.000000
# max    158956.000000      14.000000      11.000000       6.000000
#
#                ROOMS          BEDRM            AYB       YR_RMDL  \
# count  158957.000000  158957.000000  158686.000000  80928.000000
# mean        6.187736       2.732506    1941.987579   1998.243537
# std         2.618165       1.358864      33.640234     16.575786
# min         0.000000       0.000000    1754.000000     20.000000
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'BATHRM', 'HF_BATHRM', 'HEAT', 'AC', 'NUM_UNITS', 'ROOMS',
#        'BEDRM', 'AYB', 'YR_RMDL', 'EYB', 'STORIES', 'SALEDATE', 'PRICE',
#        'QUALIFIED', 'SALE_NUM', 'GBA', 'BLDG_NUM', 'STYLE', 'STRUCT', 'GRADE',
#        'CNDTN', 'EXTWALL', 'ROOF', 'INTWALL', 'KITCHENS', 'FIREPLACES',
#        'USECODE', 'LANDAREA', 'GIS_LAST_MOD_DTTM', 'SOURCE', 'CMPLX_NUM',
#        'LIVING_GBA', 'FULLADDRESS', 'CITY', 'STATE', 'ZIPCODE', 'NATIONALGRID',
#        'LATITUDE', 'LONGITUDE', 'ASSESSMENT_NBHD', 'ASSESSMENT_SUBNBHD',
#        'CENSUS_TRACT', 'CENSUS_BLOCK', 'WARD', 'SQUARE', 'X', 'Y', 'QUADRANT'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# BATHRM                  int64
# HF_BATHRM               int64
# HEAT                   object
# AC                     object
# NUM_UNITS             float64
# ROOMS                   int64
# BEDRM                   int64
# AYB                   float64
# YR_RMDL               float64
# EYB                     int64
# STORIES               float64
# SALEDATE               object
# PRICE                 float64
# QUALIFIED              object
# SALE_NUM                int64
# GBA                   float64
# BLDG_NUM                int64
# STYLE                  object
# STRUCT                 object
# GRADE                  object
# CNDTN                  object
# EXTWALL                object
# ROOF                   object
# INTWALL                object
# KITCHENS              float64
# FIREPLACES              int64
# USECODE                 int64
# LANDAREA                int64
# GIS_LAST_MOD_DTTM      object
# SOURCE                 object
# ...

# %%
df.count()
# Out:
# Unnamed: 0            158957
# BATHRM                158957
# HF_BATHRM             158957
# HEAT                  158957
# AC                    158957
# NUM_UNITS             106696
# ROOMS                 158957
# BEDRM                 158957
# AYB                   158686
# YR_RMDL                80928
# EYB                   158957
# STORIES               106652
# SALEDATE              132187
# PRICE                  98216
# QUALIFIED             158957
# SALE_NUM              158957
# GBA                   106696
# BLDG_NUM              158957
# STYLE                 106696
# STRUCT                106696
# GRADE                 106696
# CNDTN                 106696
# EXTWALL               106696
# ROOF                  106696
# INTWALL               106696
# KITCHENS              106695
# FIREPLACES            158957
# USECODE               158957
# LANDAREA              158957
# GIS_LAST_MOD_DTTM     158957
# SOURCE                158957
# CMPLX_NUM              52261
# ...

# %%
filename = "datasets/DC_Properties.csv"
df_missing = pd.read_csv(filename)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (18,19,20,21,22,23,24,33,34,35,37,43,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_missing.isnull().sum()
# Out:
# Unnamed: 0                 0
# BATHRM                     0
# HF_BATHRM                  0
# HEAT                       0
# AC                         0
# NUM_UNITS              52261
# ROOMS                      0
# BEDRM                      0
# AYB                      271
# YR_RMDL                78029
# EYB                        0
# STORIES                52305
# SALEDATE               26770
# PRICE                  60741
# QUALIFIED                  0
# SALE_NUM                   0
# GBA                    52261
# BLDG_NUM                   0
# STYLE                  52261
# STRUCT                 52261
# GRADE                  52261
# CNDTN                  52261
# EXTWALL                52261
# ROOF                   52261
# INTWALL                52261
# KITCHENS               52262
# FIREPLACES                 0
# USECODE                    0
# LANDAREA                   0
# GIS_LAST_MOD_DTTM          0
# SOURCE                     0
# CMPLX_NUM             106696
# ...

# %%
nf = df[['HEAT','BATHRM','HF_BATHRM','BEDRM','ROOMS','LANDAREA','PRICE','STYLE','FULLADDRESS','WARD']]

# %%
nf.loc[nf['PRICE'] <= 50000 ]
# Out:
#                  HEAT  BATHRM  HF_BATHRM  BEDRM  ROOMS  LANDAREA    PRICE  \
# 20      Hot Water Rad       3          1      5     14      2090  33232.0
# 25      Hot Water Rad       1          0      4      8      2090  20000.0
# 433     Hot Water Rad       3          0      3     11      1190   4500.0
# 638         Warm Cool       2          0      4      9      1400  45000.0
# 1104    Hot Water Rad       1          0      3      6      1248  50000.0
# 1186       Forced Air       2          0      3      6       616  30000.0
# 1567    Hot Water Rad       3          0      6     11      1867  25000.0
# 1593    Hot Water Rad       1          0      2      5       572  45954.0
# 1916    Hot Water Rad       4          0      4     12      1986  28000.0
# 2446    Hot Water Rad       2          0      4     10      1800  32000.0
# 2681    Hot Water Rad       3          0      4     12       981  41000.0
# 3293       Forced Air       2          0      4      7      1288  48000.0
# ...

# %%
nf.loc[nf['PRICE'] <= 20000 ]
# Out:
#                  HEAT  BATHRM  HF_BATHRM  BEDRM  ROOMS  LANDAREA    PRICE  \
# 25      Hot Water Rad       1          0      4      8      2090  20000.0
# 433     Hot Water Rad       3          0      3     11      1190   4500.0
# 3330    Hot Water Rad       2          1      4      9      1398    936.0
# 4199    Hot Water Rad       1          1      3      6      1360   1377.0
# 4888    Hot Water Rad       1          0      3      6       882  20000.0
# 5516    Hot Water Rad       2          1      7     15      2031    500.0
# 5827    Hot Water Rad       1          1      3      6       756  20000.0
# 7396       Forced Air       3          1      5     10      2030    250.0
# 13179   Hot Water Rad       1          0      3      6      1477  12000.0
# 13556      Forced Air       1          0      3      6      1167  15000.0
# 14041   Hot Water Rad       2          0      2      6       527    250.0
# 16109      Forced Air       2          0      3      6      1758  20000.0
# ...

# %%
nf_no_missing = nf.dropna()
nf_no_missing.head()
# Out:
#             HEAT  BATHRM  HF_BATHRM  BEDRM  ROOMS  LANDAREA      PRICE  \
# 0      Warm Cool       4          0      4      8      1680  1095000.0
# 2  Hot Water Rad       3          1      5      9      1680  2100000.0
# 3  Hot Water Rad       3          1      5      8      1680  1602000.0
# 5  Hot Water Rad       3          2      5     10      2196  1950000.0
# 7  Hot Water Rad       3          1      4      8      1627  1050000.0
#
#      STYLE           FULLADDRESS    WARD
# 0  3 Story  1748 SWANN STREET NW  Ward 2
# 2  3 Story  1744 SWANN STREET NW  Ward 2
# 3  3 Story  1742 SWANN STREET NW  Ward 2
# 5  4 Story      1709 S STREET NW  Ward 2
# 7  3 Story  1746 1/2 T STREET NW  Ward 2

# %%
nf.groupby(['PRICE','BEDRM','BATHRM','HF_BATHRM','HEAT']).mean()
# Out:
#                                                        ROOMS       LANDAREA
# PRICE       BEDRM BATHRM HF_BATHRM HEAT
# 1.0         1     1      0         Forced Air       3.000000      93.000000
#             2     2      0         Forced Air       4.000000     280.000000
#             3     1      1         Hot Water Rad    7.000000    4400.000000
#                   2      0         Hot Water Rad    6.000000     807.000000
#             6     3      0         Forced Air      14.000000    7811.000000
# 10.0        2     1      0         Hot Water Rad    5.000000    1264.000000
#             3     1      0         Hot Water Rad    6.000000    1031.000000
#                   2      0         Hot Water Rad    8.000000    3323.000000
#                          1         Hot Water Rad    8.000000    2400.000000
# 250.0       2     1      0         Air Exchng       5.000000    2216.000000
#                   2      0         Hot Water Rad    6.750000    1147.750000
# ...

# %%
bins = [0,30000,100000,250000,100000000]
group_names = ['Affordable','Mid_range','Expensive','Ridiculous']
nf['Affordability'] = pd.cut(nf['PRICE'], bins, labels=group_names)
nf.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#             HEAT  BATHRM  HF_BATHRM  BEDRM  ROOMS  LANDAREA      PRICE  \
# 0      Warm Cool       4          0      4      8      1680  1095000.0
# 1      Warm Cool       3          1      5     11      1680        NaN
# 2  Hot Water Rad       3          1      5      9      1680  2100000.0
# 3  Hot Water Rad       3          1      5      8      1680  1602000.0
# 4      Warm Cool       2          1      3     11      2032        NaN
#
#      STYLE                   FULLADDRESS    WARD Affordability
# ...

# %%
nf.groupby(['Affordability','STYLE']).mean()
# Out:
#                                  BATHRM  HF_BATHRM     BEDRM      ROOMS  \
# Affordability STYLE
# Affordable    1 Story          1.266667   0.133333  2.200000   5.666667
#               1.5 Story Fin    1.750000   0.500000  2.750000   6.250000
#               1.5 Story Unfin       NaN        NaN       NaN        NaN
#               2 Story          1.761364   0.278409  3.102273   7.125000
#               2.5 Story Fin    2.500000   1.250000  4.250000   9.000000
#               2.5 Story Unfin  1.000000   0.000000  3.000000   6.000000
#               3 Story          2.800000   0.400000  4.266667   9.400000
#               3.5 Story Fin         NaN        NaN       NaN        NaN
#               3.5 Story Unfin       NaN        NaN       NaN        NaN
#               4 Story               NaN        NaN       NaN        NaN
#               4.5 Story Fin         NaN        NaN       NaN        NaN
#               4.5 Story Unfin       NaN        NaN       NaN        NaN
# ...

# %%
nf.groupby(['STYLE','Affordability']).mean()
# Out:
#                                  BATHRM  HF_BATHRM     BEDRM      ROOMS  \
# STYLE           Affordability
# 1 Story         Affordable     1.266667   0.133333  2.200000   5.666667
#                 Mid_range      1.283237   0.236994  2.450867   5.554913
#                 Expensive      1.495130   0.342532  2.740260   5.974026
#                 Ridiculous     2.244983   0.408863  3.309365   6.897157
# 1.5 Story Fin   Affordable     1.750000   0.500000  2.750000   6.250000
#                 Mid_range      1.296296   0.370370  2.648148   6.351852
#                 Expensive      1.529197   0.383212  3.036496   6.598540
#                 Ridiculous     2.374092   0.438257  3.558111   7.315981
# 1.5 Story Unfin Affordable          NaN        NaN       NaN        NaN
#                 Mid_range      1.000000   0.000000  2.333333   5.000000
#                 Expensive      1.294118   0.411765  2.588235   5.823529
#                 Ridiculous     2.411765   0.264706  3.205882   7.441176
# ...
